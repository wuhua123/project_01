# %%
# %matplotlib notebook
from cryptocmd import CmcScraper
import pandas as pd
import time
import seaborn as sb
import matplotlib.pyplot as plt
import datetime
import numpy as np
import time
import matplotlib.mlab as mlab
import string
from datetime import datetime, timedelta

# %%
#current date
Current_date = time.strftime("%d-%m-%Y")
Current_date
# Out:
# '12-11-2018'

# %%
# scraping data
scraper_btc = CmcScraper("btc")
scraper_eth = CmcScraper("eth")
scraper_xrp = CmcScraper("xrp")
scraper_eos = CmcScraper("eos")
scraper_bch = CmcScraper("bch")
scraper_xlm = CmcScraper("xlm")
scraper_ltc = CmcScraper("ltc")
scraper_ada = CmcScraper("ada")
scraper_xmr = CmcScraper("xmr")
scraper_trx = CmcScraper("trx")


# converting to csv
#scraper_btc.export_csv("btc_all_time.csv")
#scraper_eth.export_csv("eth_all_time.csv")
#scraper_xrp.export_csv("xrp_all_time.csv")
#scraper_eos.export_csv("eos_all_time.csv")
#scraper_bch.export_csv("bch_all_time.csv")
#scraper_xlm.export_csv("xlm_all_time.csv")
#scraper_ltc.export_csv("ltc_all_time.csv")
#scraper_ada.export_csv("ada_all_time.csv")
#scraper_xmr.export_csv("xmr_all_time.csv")
#scraper_trx.export_csv("trx_all_time.csv")

# %%
# place into a dataframe
df_btc = scraper_btc.get_dataframe()
df_eth = scraper_eth.get_dataframe()
df_xrp = scraper_xrp.get_dataframe()
df_eos = scraper_eos.get_dataframe()
df_bch = scraper_bch.get_dataframe()
df_xlm = scraper_xlm.get_dataframe()
df_ltc = scraper_ltc.get_dataframe()
df_ada = scraper_ada.get_dataframe()
df_xmr = scraper_xmr.get_dataframe()
df_trx = scraper_trx.get_dataframe()

# %%
# new data frame with the last 2 years

df_btc_2y = df_btc.loc[df_btc['Date'] >= "2016-11-01", :]
df_eth_2y = df_eth.loc[df_eth['Date'] >= "2016-11-01", :]
df_xrp_2y = df_xrp.loc[df_xrp['Date'] >= "2016-11-01", :]
df_eos_2y = df_eos.loc[df_eos['Date'] >= "2016-11-01", :]
df_bch_2y = df_bch.loc[df_bch['Date'] >= "2016-11-01", :]
df_xlm_2y = df_xlm.loc[df_xlm['Date'] >= "2016-11-01", :]
df_ltc_2y = df_ltc.loc[df_ltc['Date'] >= "2016-11-01", :]
df_ada_2y = df_ada.loc[df_ada['Date'] >= "2016-11-01", :]
df_xmr_2y = df_xmr.loc[df_xmr['Date'] >= "2016-11-01", :]
df_trx_2y = df_trx.loc[df_trx['Date'] >= "2016-11-01", :]

# new data frame with the last 1 years

#df_btc_1y = df_btc.loc[df_btc['Date'] >= "2017-11-01", :]
#df_eth_1y = df_eth.loc[df_eth['Date'] >= "2017-11-01", :]
#df_xrp_1y = df_xrp.loc[df_xrp['Date'] >= "2017-11-01", :]
#df_eos_1y = df_eos.loc[df_eos['Date'] >= "2017-11-01", :]
#df_bch_1y = df_bch.loc[df_bch['Date'] >= "2017-11-01", :]
#df_xlm_1y = df_xlm.loc[df_xlm['Date'] >= "2017-11-01", :]
#df_ltc_1y = df_ltc.loc[df_ltc['Date'] >= "2017-11-01", :]
#df_ada_1y = df_ada.loc[df_ada['Date'] >= "2017-11-01", :]
#df_xmr_1y = df_xmr.loc[df_xmr['Date'] >= "2017-11-01", :]
#df_trx_1y = df_trx.loc[df_trx['Date'] >= "2017-11-01", :]

# new data frame 6 months

#df_btc_6m = df_btc.loc[df_btc['Date'] >= "2017-05-01", :]
#df_eth_6m = df_eth.loc[df_eth['Date'] >= "2017-05-01", :]
#df_xrp_6m = df_xrp.loc[df_xrp['Date'] >= "2017-05-01", :]
#df_eos_6m = df_eos.loc[df_eos['Date'] >= "2017-05-01", :]
#df_bch_6m = df_bch.loc[df_bch['Date'] >= "2017-05-01", :]
#df_xlm_6m = df_xlm.loc[df_xlm['Date'] >= "2017-05-01", :]
#df_ltc_6m = df_ltc.loc[df_ltc['Date'] >= "2017-05-01", :]
#df_ada_6m = df_ada.loc[df_ada['Date'] >= "2017-05-01", :]
#df_xmr_6m = df_xmr.loc[df_xmr['Date'] >= "2017-05-01", :]
#df_trx_6m = df_trx.loc[df_trx['Date'] >= "2017-05-01", :]

# new data frame 1 months

#df_btc_1m = df_btc.loc[df_btc['Date'] >= "2017-10-01", :]
#df_eth_1m = df_eth.loc[df_eth['Date'] >= "2017-10-01", :]
#df_xrp_1m = df_xrp.loc[df_xrp['Date'] >= "2017-10-01", :]
#df_eos_1m = df_eos.loc[df_eos['Date'] >= "2017-10-01", :]
#df_bch_1m = df_bch.loc[df_bch['Date'] >= "2017-10-01", :]
#df_xlm_1m = df_xlm.loc[df_xlm['Date'] >= "2017-10-01", :]
#df_ltc_1m = df_ltc.loc[df_ltc['Date'] >= "2017-10-01", :]
#df_ada_1m = df_ada.loc[df_ada['Date'] >= "2017-10-01", :]
#df_xmr_1m = df_xmr.loc[df_xmr['Date'] >= "2017-10-01", :]
#df_trx_1m = df_trx.loc[df_trx['Date'] >= "2017-10-01", :]

# %%
# Combine Data by Market Cap

df_crypto_marketCap = pd.DataFrame({"Date": df_btc["Date"],
                          "BTC Cap":df_btc_2y["Market Cap"], 
                          "ETH Cap": df_eth_2y["Market Cap"],
                          "XRP Cap": df_xrp_2y['Market Cap'],
                          "BCH Cap": df_bch_2y['Market Cap'],
                          "EOS Cap": df_eos_2y['Market Cap'],
                          "XLM Cap": df_xlm_2y['Market Cap'],
                          "LTC Cap": df_ltc_2y['Market Cap'],
                          "ADA Cap": df_ada_2y['Market Cap'],
                          "XMR Cap": df_xmr_2y['Market Cap'],
                          "TRX Cap": df_trx_2y['Market Cap'],
                         })
# Combine data by Volume
df_crypto_volume = pd.DataFrame({"Date": df_btc_2y["Date"],
                          "BTC Vol": df_btc_2y["Volume"], 
                          "ETH Vol": df_eth_2y["Volume"],
                          "XRP Vol": df_xrp_2y['Volume'],
                          "BCH Vol": df_bch_2y['Volume'],
                          "EOS Vol": df_eos_2y['Volume'],
                          "XLM Vol": df_xlm_2y['Volume'],
                          "LTC Vol": df_ltc_2y['Volume'],
                          "ADA Vol": df_ada_2y['Volume'],
                          "XMR Vol": df_xmr_2y['Volume'],
                          "TRX Vol": df_trx_2y['Volume'],
                         })

df_crypto_volume.head()
# Out:
#         Date     BTC Vol     ETH Vol    XRP Vol      BCH Vol      EOS Vol  \
# 0 2018-11-11  3939060000  1501600000  292675000  693990000.0  729699000.0
# 1 2018-11-10  3705320000  1377760000  328038000  656843000.0  595931000.0
# 2 2018-11-09  4346820000  1554750000  509865000  860474000.0  719946000.0
# 3 2018-11-08  4665260000  1769080000  686221000  824619000.0  655039000.0
# 4 2018-11-07  4941260000  1927830000  631230000  935156000.0  719042000.0
#
#      XLM Vol    LTC Vol     ADA Vol   XMR Vol      TRX Vol
# 0  109488000  410262000  23663500.0  14920300   46834800.0
# 1   53086500  322713000  15012100.0  11667700   50249500.0
# 2   71764800  386711000  23756800.0  13896100   52900400.0
# 3   88138000  351857000  32149600.0  15042800   59261300.0
# 4   78967900  385412000  36852900.0  14328200  124654000.0

# %%
#Look for top 5 cryptos for the time being

# sort based on market cap
most_update = df_crypto_marketCap.loc[0,:]
most_update = most_update.drop("Date")

#print(most_update)

most_update_sort = most_update.sort_values(ascending=False )


# Finding the current top 5 crypto currencies based on Market Capital
top_five = most_update_sort.head()

#top_five_names = [top_five.index[i] for i in range(0,5)]
#top_five_values = [top_five.values[i] for i in range(0,5)]

#print(top_five)
#print(top_five.dtype)

top5_cryptos = pd.DataFrame({"Name": [top_five.index[i] for i in range(0,5)],
             "Market Capital":[top_five.values[i] for i in range(0,5)] })

for i in range(0, 5):
    
    top5_cryptos.loc[i, 'Name'] = str(top5_cryptos.loc[i,'Name'])
    short_name = top5_cryptos.loc[i, 'Name'].split()[0]
    top5_cryptos.loc[i, 'Name'] = short_name
    #top5_cryptos.to_string(top5_cryptos.loc[i, 'Name'])

#top5_cryptos['Name'] = top5_cryptos.to_string(columns=['Name'])
print(top5_cryptos)
print(top5_cryptos['Name'].dtype)
# Out:
#   Name  Market Capital
# 0  BTC    1.113735e+11
# 1  ETH    2.179846e+10
# 2  XRP    2.034049e+10
# 3  BCH    9.308507e+09
# 4  XLM    5.181328e+09
# object

# %%
# Graph top 5 cryptos
# %matplotlib notebook

#top5_cryptos_graph = top5_cryptos.set_index('Name')
x_axis = np.arange(len(top5_cryptos['Market Capital']))

plt.bar(x_axis, top5_cryptos['Market Capital'], color='blue', align='center')

tick_locations = [i for i in x_axis]
tick_names = top5_cryptos['Name']
plt.xticks(tick_locations, tick_names)

plt.title("Top 5 Cryptos for the time being")
plt.ylabel("Market Capital")

#plt.rcdefaults()
#fig, ax = plt.subplots()

# Example data
#y_pos = np.arange(len(top_five_names))
#error = np.random.rand(len(top_five_names))

#ax.barh(y_pos, top_five_values, xerr=error, align='center', color='blue', ecolor='black')
#ax.set_yticks(y_pos)
#ax.set_yticklabels(top_five_names)
#ax.invert_yaxis()  # labels read top-to-bottom
#ax.set_xlabel('Crypto Market Cap')
#ax.set_title('Top 5 Cryptos for the time being')

plt.savefig("graphs/Top5.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#prepare for further data retrieving
#crypto_code = ['BTC', 'ETH', 'XRP', 'EOS', 'BCH', 'XLM', 'LTC', 'ADA', 'XMR', 'TRX']

all_cryptos_allPeriods ={'BTC': [df_btc, df_btc_2y],
                         'ETH': [df_eth, df_eth_2y], 
                         'XRP': [df_xrp, df_xrp_2y],
                         'EOS': [df_eos, df_eos_2y],
                         'BCH': [df_bch, df_bch_2y],
                         'XLM': [df_xlm, df_xlm_2y],
                         'LTC': [df_ltc, df_ltc_2y],
                         'ADA': [df_ada, df_ada_2y],
                         'XMR': [df_xmr, df_xmr_2y],
                         'TRX': [df_trx, df_trx_2y]}

#print(all_cryptos_allPeriods['BTC'])
cryptos_2y = []
cryptos_2y_names = []

for name in top5_cryptos['Name']:
    cryptos_2y.append(all_cryptos_allPeriods[name][1])
    cryptos_2y_names.append(name)

#print(cryptos_2y[0].head())
#print(cryptos_2y[1].head())
#print(cryptos_2y[2].head())
#print(cryptos_2y[3].head())
#print(cryptos_2y[4].head())
#print(cryptos_2y_names)
# calculate Daily Change Percentage for top 5 cryptos
for i in range(0,5):
    cryptos_2y[i]["Daily Change Percent(%)"] = ((cryptos_2y[i]["Close"] - cryptos_2y[i]["Close"].shift(-1))/cryptos_2y[i]["Close"].shift(-1))*100
    cryptos_2y[i] = cryptos_2y[i].dropna()
# Out:
# C:\Users\wuhua\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#Percentage change and create a new data frame 

#Bitcoin dataframe for 2 years data
#df_btc_2y["Daily Change Percent(%)"] = ((df_btc_2y["Close"] - df_btc_2y["Close"].shift(-1))/df_btc_2y["Close"].shift(-1))*100
#df_btc_2y = df_btc_2y.dropna()

#df_btc_1y["Daily Change Percent(%)"] = ((df_btc_1y["Close"] - df_btc_1y["Close"].shift(-1))/df_btc_1y["Close"].shift(-1))*100
#df_btc_6m["Daily Change Percent(%)"] = ((df_btc_6m["Close"] - df_btc_6m["Close"].shift(-1))/df_btc_6m["Close"].shift(-1))*100
#df_btc_1m["Daily Change Percent(%)"] = ((df_btc_1m["Close"] - df_btc_1m["Close"].shift(-1))/df_btc_6m["Close"].shift(-1))*100

#Etheurum
#df_eth_2y["Daily Change Percent(%)"] = ((df_eth_2y["Close"] - df_eth_2y["Close"].shift(-1))/df_eth_2y["Close"].shift(-1))*100
#df_eth_2y = df_eth_2y.dropna()

#Ripple
#df_xrp_2y["Daily Change Percent(%)"] = ((df_xrp_2y["Close"] - df_xrp_2y["Close"].shift(-1))/df_xrp_2y["Close"].shift(-1))*100
#df_xrp_2y = df_xrp_2y.dropna()

# Bitcoin Cash
#df_bch_2y["Daily Change Percent(%)"] = ((df_bch_2y["Close"] - df_bch_2y["Close"].shift(-1))/df_bch_2y["Close"].shift(-1))*100
#df_bch_2y = df_bch_2y.dropna()

# EOS
#df_eos_2y["Daily Change Percent(%)"] = ((df_eos_2y["Close"] - df_eos_2y["Close"].shift(-1))/df_eos_2y["Close"].shift(-1))*100
#df_eos_2y = df_eos_2y.dropna()

#Cleaning by dropping null value rows.

#cryptos = [df_btc_2y, df_eth_2y, df_xrp_2y, df_bch_2y, df_eos_2y]

#prepare for further data retrieving
#crypto_code = ['BTC', 'ETH', 'XRP', 'EOS', 'BCH', 'XLM', 'LTC', 'ADA', 'XMR', 'TRX']


              
#for i in range(0,5):
 #   cryptos_2y[i]["Daily Change Percent(%)"] = ((cryptos_2y[i]["Close"] - cryptos_2y[i]["Close"].shift(-1))/cryptos_2y[i]["Close"].shift(-1))*100
  #  cryptos_2y = cryptos_2y[i].dropna()

# %%
#numpy.std- Standard Deviation
cryptos_2ydev = []
for i in range(0,5):
    cryptos_2ydev.append(np.std(cryptos_2y[i]["Daily Change Percent(%)"], axis=0))
    print(cryptos_2ydev[i])

#df_btc_2ydev = np.std(df_btc_2y["Daily Change Percent(%)"], axis=0)
#df_eth_2ydev = np.std(df_eth_2y["Daily Change Percent(%)"], axis=0)
#df_xrp_2ydev = np.std(df_xrp_2y["Daily Change Percent(%)"], axis=0)
#df_bch_2ydev = np.std(df_bch_2y["Daily Change Percent(%)"], axis=0)
#df_eos_2ydev = np.std(df_eos_2y["Daily Change Percent(%)"], axis=0)


#df_btc_1ydev = np.std(df_btc_1y["Daily Change Percent(%)"], axis=0)
#df_btc_6mdev = np.std(df_btc_6m["Daily Change Percent(%)"], axis=0)
#df_btc_1mdev = np.std(df_btc_1m["Daily Change Percent(%)"], axis=0)

#print(df_btc_2ydev)
#print(df_eth_2ydev)
#print(df_xrp_2ydev)
#print(df_bch_2ydev)
#print(df_eos_2ydev)
# Out:
# 4.4608592439740855
# 6.363443863603103
# 11.1680283569949
# 9.538031554711983
# 11.36134876634434

# %%
#Middle Band = 20 day moving average
# Calculating the short-window simple moving average
#btc_5sma = df_btc_2y['Close'].rolling(window=5).mean()
#btc_20sma = df_btc_2y['Close'].rolling(window=20).mean()
#btc_50sma = df_btc_2y['Close'].rolling(window=50).mean()

#btc_50sma.dropna()
#btc_20sma.dropna()
#btc_50sma.dropna()

# %%
#np.random.seed(0)

n_bins = 10
x = np.random.randn(1000, 3)
print(x)

print(x.dtype)

fig, axes = plt.subplots(nrows=2, ncols=2)
ax0, ax1, ax2, ax3 = axes.flatten()

colors = ['red', 'tan', 'lime']
ax0.hist(x, n_bins, normed=1, histtype='bar', color=colors, label=colors)
ax0.legend(prop={'size': 10})
ax0.set_title('bars with legend')
# Out:
# [[-0.66501893  1.20028769 -0.72328195]
#  [ 0.7733014  -0.21271193  0.25033263]
#  [ 0.04636293 -0.33111899  1.07164687]
#  ...
#  [ 0.20955457  0.15578443  0.63031266]
#  [ 0.09317591  0.72643692  0.46509348]
#  [ 0.98133565 -0.77427852 -1.53435317]]
# float64
# <img src="data:image/png;base64,..." width="640">
# C:\Users\wuhua\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,'bars with legend')

# %%
# %matplotlib notebook



cryptos_daily_c_pct = []

for i in range(0, 5):
    temp_df = cryptos_2y[i][['Date', 'Daily Change Percent(%)']]
    temp_df = temp_df.rename(columns={'Daily Change Percent(%)': cryptos_2y_names[i]})
    #print(temp_df.head())
    cryptos_daily_c_pct.append(temp_df)
    
#print(cryptos_daily_c_pct[0].head())
#print(cryptos_daily_c_pct[1].head())
#print(cryptos_daily_c_pct[2].head())
#print(cryptos_daily_c_pct[3].head())
#print(cryptos_daily_c_pct[4].head())
    

#daily_c_pct_df = cryptos_daily_c_pct[0]
#for i in range(1, 5):
#    daily_c_pct_df = pd.merge(daily_c_pct_df,  cryptos_daily_c_pct[i], on='Date')
#cryptos_2y = []
#cryptos_2y_names = []
temp_1 = pd.merge(cryptos_daily_c_pct[0], cryptos_daily_c_pct[1], on='Date')
temp_1 = temp_1.rename(columns={'Daily Change Percent(%)_x': cryptos_2y_names[0],
                                                  'Daily Change Percent(%)_y': cryptos_2y_names[1],})
#print(daily_c_pct_df1)
temp_2 = pd.merge(cryptos_daily_c_pct[2], cryptos_daily_c_pct[3], on='Date')
temp_2 = temp_2.rename(columns={'Daily Change Percent(%)_x': cryptos_2y_names[2],
                                                  'Daily Change Percent(%)_y': cryptos_2y_names[3],})

temp_3 = pd.merge(temp_1, temp_2)
daily_c_pct_df = pd.merge(temp_3, cryptos_daily_c_pct[4], on = 'Date')

print(daily_c_pct_df.head())

    
#print(daily_c_pct_df.head())
#print(daily_c_pct_df.columns)

#pd.concat([s3, s4, s5], axis=1, keys=['red','blue','yellow'])

#x = pd.concat([daily_c_pct_df.iloc[:,1], \
 #          daily_c_pct_df.iloc[:,2], \
  #         daily_c_pct_df.iloc[:,3], \
   #        daily_c_pct_df.iloc[:,4], \
    #       daily_c_pct_df.iloc[:,5]], \
     #     axis=1, keys=[cryptos_2y_names[0], cryptos_2y_names[1], cryptos_2y_names[2],\
      #                  cryptos_2y_names[3], cryptos_2y_names[4]])
    
#x = pd.concat([daily_c_pct_df['Daily Change Percent(%)_x'], \
 #              daily_c_pct_df['Daily Change Percent(%)_y'], \
  #             daily_c_pct_df['Daily Change Percent(%)_x'], \
   #            daily_c_pct_df['Daily Change Percent(%)_y'], \
    #           daily_c_pct_df['Daily Change Percent(%)'], \
     #          axis=1, keys=[cryptos_2y_names[0], cryptos_2y_names[1], cryptos_2y_names[2],\
      #                       cryptos_2y_names[3], cryptos_2y_names[4]])

#print(x)

n_bins = 10
#print(daily_c_pct_df[cryptos_2y_names[0]])

#x = np.array([daily_c_pct_df[cryptos_2y_names[0]], daily_c_pct_df[cryptos_2y_names[1]]], axis=1)

#for i in range(0, len(daily_c_pct_df)):
 #   data = [[daily_c_pct_df.loc[i, cryptos_2y_names[0]], daily_c_pct_df.loc[i, cryptos_2y_names[1]],\
  #           daily_c_pct_df.loc[i, cryptos_2y_names[2]], daily_c_pct_df.loc[i, cryptos_2y_names[3]],\
   #         daily_c_pct_df.loc[i, cryptos_2y_names[4]]]]
    

x = daily_c_pct_df[[cryptos_2y_names[0],cryptos_2y_names[1],cryptos_2y_names[2],cryptos_2y_names[3],cryptos_2y_names[4]]].as_matrix()

# X = df[['Res_fs1','Res_fs2','Res_ps1','Res_ps2']].values
print(x)

fig, ax = plt.subplots(nrows=1, ncols=1)
#ax0, ax1 = axes.flatten()

#fig = plt.figure(figsize=(20,7))
#ax = plt.subplots(nrows=1, ncols=1)
colors = ['red', 'blue', 'green', 'orange', 'purple']
labels = [cryptos_2y_names[0],cryptos_2y_names[1],cryptos_2y_names[2],cryptos_2y_names[3],cryptos_2y_names[4]]
ax.hist(x, n_bins, histtype='bar', color=colors, label=labels)
ax.legend(prop={'size': 10})
ax.set_title('bars with legend')


#for i in range(0, 5):
 #   ("ax"+str(i)).hist(daily_c_pct.plot(kind='hist', title= cryptos_2y_names[i], color="blue")
# Out:
#         Date       BTC       ETH       XRP       BCH       XLM
# 0 2018-11-11  0.031985 -0.559921 -0.154925 -4.161725  4.737205
# 1 2018-11-10  0.369580  1.171038  1.204391  2.218875  2.225857
# 2 2018-11-09 -1.055205 -1.017764  1.450838 -5.224309 -0.195670
# 3 2018-11-08 -1.170266 -2.279215 -7.877254 -6.937222 -0.262934
# 4 2018-11-07  1.069957 -0.581369 -2.435529 -1.791539 -3.342671
# [[  0.03198517  -0.55992095  -0.15492463  -4.16172507   4.73720476]
#  [  0.3695804    1.17103823   1.20439093   2.21887513   2.2258572 ]
#  [ -1.05520537  -1.01776375   1.45083768  -5.22430932  -0.19567026]
#  ...
#  [ -1.82535863  -1.33520391  -2.40421327 -10.09584665   1.76270821]
#  [ -6.47510218  -8.01032442  -7.23846627  -7.66961652 -17.93408538]
#  [  0.89583944  -0.54879398  -1.56671349   6.69152181   3.8403234 ]]
# C:\Users\wuhua\Anaconda3\lib\site-packages\ipykernel_launcher.py:73: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# ...

# %%
#plt.xlabel("Daily Change Percentage")
    
#files.append(cryptos_2y_names[i]+".png")
#plt.savefig("graphs/distribution/files[i]")

#fig, axes = plt.subplots(nrows=1, ncols=5)

#def plt_graph(x, graph_title, horiz_label, ax):
    #df[x].plot(kind='barh', ax=ax)

#plt_graph("framekey", "Some title", "some label", axes[4])


daily_c_pct = df_btc_2y["Daily Change Percent(%)"]

#print(daily_c_pct)
daily_c_pct.plot(kind='hist', title= "Bitcoin: 2016-11-03 to 2018-11-09 ", color="blue")

plt.xlabel("Daily Change Percentage")

plt.savefig("graphs/distribution/bitcoin_pct_frq.png")


#daily_c_pct = df_eth_2y["Daily Change Percent(%)"]
#daily_c_pct.plot(kind='hist', title= "Ethereum Daily Change Percentage Distribution", color="blue")

#plt.savefig("graphs/distribution/Eth_pct_frq.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#print(df_btc_2y)

#plt.hlines(df_btc_2ydev, 0, 24, alpha=0.25)
#print(df_btc_2ydev)
#print(df_eth_2ydev)
#print(df_xrp_2ydev)
#print(df_bch_2ydev)
#print(df_eos_2ydev)

# %%
# resample daily change percentage weekly

#Bitcoin
start_date = df_btc_2y['Date'].min()
start_date = start_date.strftime('%Y-%m-%d')
end_date = df_btc_2y['Date'].max()
end_date = end_date.strftime('%Y-%m-%d')

Index = pd.DatetimeIndex(start=start_date, end=end_date, freq="D")
daily_change_pct = df_btc_2y["Daily Change Percent(%)"].tolist()
s_btc_pct = pd.DataFrame({"Daily Change Percent(%)": daily_change_pct}, index=Index)
btc_pct = s_btc_pct.resample(rule="M",how=np.std)
btc_pct_dev = btc_pct["Daily Change Percent(%)"]

#print(btc_pct_dev)

#Ethereum
start_date = df_eth_2y['Date'].min()
start_date = start_date.strftime('%Y-%m-%d')
end_date = df_eth_2y['Date'].max()
end_date = end_date.strftime('%Y-%m-%d')

Index = pd.DatetimeIndex(start=start_date, end=end_date, freq="D")
daily_change_pct = df_eth_2y["Daily Change Percent(%)"].tolist()
s_eth_pct = pd.DataFrame({"Daily Change Percent(%)": daily_change_pct}, index=Index)
eth_pct = s_eth_pct.resample(rule="M",how=np.std)
eth_pct_dev = eth_pct["Daily Change Percent(%)"]

#print(eth_pct_dev)

#Ripple
start_date = df_xrp_2y['Date'].min()
start_date = start_date.strftime('%Y-%m-%d')
end_date = df_xrp_2y['Date'].max()
end_date = end_date.strftime('%Y-%m-%d')

Index = pd.DatetimeIndex(start=start_date, end=end_date, freq="D")
daily_change_pct = df_xrp_2y["Daily Change Percent(%)"].tolist()
s_xrp_pct = pd.DataFrame({"Daily Change Percent(%)": daily_change_pct}, index=Index)
xrp_pct = s_xrp_pct.resample(rule="M",how=np.std)
xrp_pct_dev = xrp_pct["Daily Change Percent(%)"]

#print(xrp_pct_dev)

#Bitcoin Cash
start_date = df_bch_2y['Date'].min()
start_date = start_date.strftime('%Y-%m-%d')
end_date = df_bch_2y['Date'].max()
end_date = end_date.strftime('%Y-%m-%d')

Index = pd.DatetimeIndex(start=start_date, end=end_date, freq="D")
daily_change_pct = df_bch_2y["Daily Change Percent(%)"].tolist()
s_bch_pct = pd.DataFrame({"Daily Change Percent(%)": daily_change_pct}, index=Index)
bch_pct = s_bch_pct.resample(rule="M",how=np.std)
bch_pct_dev = bch_pct["Daily Change Percent(%)"]

#print(bch_pct_dev)

#EOS
#start_date = df_eos_2y['Date'].min()
#start_date = start_date.strftime('%Y-%m-%d')
#end_date = df_eos_2y['Date'].max()
#end_date = end_date.strftime('%Y-%m-%d')

#Index = pd.DatetimeIndex(start=start_date, end=end_date, freq="D")
#daily_change_pct = df_eos_2y["Daily Change Percent(%)"].tolist()
#s_eos_pct = pd.DataFrame({"Daily Change Percent(%)": daily_change_pct}, index=Index)
#eos_pct = s_eos_pct.resample(rule="M",how=np.std)
#eos_pct_dev = eos_pct["Daily Change Percent(%)"]


#res_df, tail_dfs = dataframes[0], dataframes[1:]
#for df in tail_dfs:
#  res_df = res_df.unionAll(df)
#crypto = ['btc', 'eth', 'xrp', 'bch', 'eos']

#Use loop for the above

#cryptos = [df_btc_2y, df_eth_2y, df_bch_2y, df_xrp_2y]
#s_cryptos_pct = [s_btc_pct, s_eth_pct, s_bch_pct, s_xrp_pct]
#cryptos_pct = [btc_pct, eth_pct, bch_pct, xrp_pct]
#cryptos_pct_dev = [btc_pct_dev, eth_pct_dev, bch_pct_dev, xrp_pct_dev]
#colors = ['blue', 'red', 'orange', 'purple']
#markers = ['s', 'o', 's', '^']
#files = ['btc_PCT_dev.png', 'eth_PCT_dev.png', 'bch_PCT_dev', 'xrp_PCT_dev']
#labels = ["BTC Monthly Deviation", "ETH Monthly Deviation", "BCH Monthly Deviation", "XRP Monthly Deviation"]

#print (cryptos[0])
#print(cryptos[0]['Date'])

#cryptos_2y

plt.figure(figsize=(10,7)) 

colors = ['blue', 'red', 'orange', 'purple', 'green']
markers = ['s', 'o', 's', '^', 'x']

#labels = [cryptos_2y_names, "ETH Monthly Deviation", "BCH Monthly Deviation", "XRP Monthly Deviation"]

for i in range(0, 5):
    
    start_date = cryptos_2y[i]['Date'].min()
    start_date = start_date.strftime('%Y-%m-%d')
    end_date = cryptos_2y[i]['Date'].max()
    end_date = end_date.strftime('%Y-%m-%d')
    
    Index = pd.DatetimeIndex(start=start_date, end=end_date, freq="D")
    daily_change_pct = cryptos_2y[i]["Daily Change Percent(%)"].tolist()
    #s_cryptos_pct[i] = pd.DataFrame({"Daily Change Percent(%)": daily_change_pct}, index=Index)
    temp1 = pd.DataFrame({"Daily Change Percent(%)": daily_change_pct}, index=Index)
    
    #resample
    #cryptos_pct[i] = df_for_st.resample(rule="M",how=np.std)
    temp2 = temp1.resample(rule="M",how=np.std)
    #cryptos_pct_dev[i] = cryptos_pct[i]["Daily Change Percent(%)"]
    monthly_dev = temp2["Daily Change Percent(%)"]
    
    
    monthly_dev.plot(marker=markers[i], color=colors[i], label=cryptos_2y_names[i])
    plt.savefig("graphs/deviation/eos_PCT_dev.png")

    
plt.legend()

plt.title("Top 5 Crypto Deviation Analyzation")
plt.xlabel("Year and Months")
plt.ylabel("Monthly Deviation")
#print(eos_pct_dev)

#fig = plt.figure(figsize=(10,6))
#fig.subplots_adjust(hspace=0.2, wspace=0.2)
#for i in range(1, 6):
#    ax = fig.add_subplot(2, 3, i)
#    ax.text(0.5, 0.5, str((2, 3, i)),
#           fontsize=18, ha='center')



#eos_pct_dev.plot(marker='^', color='purple', label="EOS Monthly Deviation")
#plt.savefig("graphs/deviation/eos_PCT_dev.png")

#xrp_pct_dev.plot(marker ='x', color='green', label="XRP Monthly Deviation")
#plt.savefig("graphs/deviation/ripple_PCT_dev.png")

#bch_pct_dev.plot(marker ='s', color='orange', label="BCH Monthly Deviation")
#plt.savefig("graphs/deviation/bch_PCT_dev.png")

#eth_pct_dev.plot(marker ='o', color='red', label="ETH Monthly Deviation")
#plt.savefig("graphs/deviation/ethereum_PCT_dev.png")

#btc_pct_dev.plot(marker ='s', color='blue', label="BTC Monthly Deviation")
#plt.savefig("graphs/deviation/bitcoin_PCT_dev.png")
# Out:
# C:\Users\wuhua\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   if sys.path[0] == '':
# C:\Users\wuhua\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
# C:\Users\wuhua\Anaconda3\lib\site-packages\ipykernel_launcher.py:40: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
# C:\Users\wuhua\Anaconda3\lib\site-packages\ipykernel_launcher.py:54: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
# <img src="data:image/png;base64,..." width="1000">
# C:\Users\wuhua\Anaconda3\lib\site-packages\ipykernel_launcher.py:114: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
# Text(91.9722,0.5,'Monthly Deviation')

# %%
# %matplotlib notebook
daily_c_pct = df_eth_2y["Daily Change Percent(%)"]
daily_c_pct.plot(kind='hist', title= "Ethereum Daily Change Percentage Distribution", color="blue")

plt.savefig("graphs/distribution/Eth_pct_frq.png")

# %%
# %matplotlib notebook

sb.distplot(a=df_eth_2y["Close"], axlabel="Daily Closing Price")
plt.title("Ethereum Price Frequency  2016-11-02 ~ 2018-11-09")

plt.savefig("graphs/distribution/ETH_price_frq.png")

# %%
#Index = pd.DatetimeIndex(start='2016-11-02', end='2018-11-09', freq="D")
#close = df_eth_2y["Close"].tolist()
#s_eth = pd.DataFrame({"Close": close}, index=Index)


#s_eth = s_eth.resample(rule="M",how=np.std)
#s_eth = s_eth.rename(columns={"Close":"Monthly Deviation"})

#%matplotlib notebook

#s_eth.plot(title='Ethereum Monthly Deviation of Closing Price in Past Two Years', figsize=(10,7), color='r', alpha=0.5)

#plt.savefig("graphs/deviation/ethereum_deviation_line.png")

# %%
# %matplotlib notebook
daily_c_pct = df_xrp_2y["Daily Change Percent(%)"]
daily_c_pct.plot(kind='hist', title="Ripple/XRP Daily Change Percentage Distribution", color="blue")

plt.savefig("graphs/distribution/Ripple_pct_frq.png")

# %%
# %matplotlib notebook

sb.distplot(a=df_xrp_2y["Close"], axlabel="Daily Closing Price")
plt.title("Ripple Price Frequency  2016-11-02 ~ 2018-11-09")

plt.savefig("graphs/distribution/Ripple_price_frq.png")

# %%
#print(df_xrp_2y)

# %%
# resample daily change percentage weekly
Index = pd.DatetimeIndex(start='2016-11-02', end='2018-11-09', freq="D")
daily_change_pct = df_xrp_2y["Daily Change Percent(%)"].tolist()
s_xrp = pd.DataFrame({"Daily Change Percent(%)": daily_change_pct}, index=Index)

#s_btc.index = pd.to_datetime(s_btc.index,format="%Y-%m-%d")

s_xrp = s_xrp.resample(rule="M",how=np.std)
#s_btc = s_btc.rename(columns={"Close":"Monthly Deviation"})

# %matplotlib notebook
#s_btc_dev = s_btc["Monthly Deviation"]
s_xrp_dev = s_xrp["Daily Change Percent(%)"]
s_eth_dev.plot(title="Ripple Deviation Distribution Based on Daily Change Percentage", color="red", alpha=0.5)

plt.savefig("graphs/deviation/XRP_PCT_dev.png")

# %%
Index = pd.DatetimeIndex(start='2016-11-02', end='2018-11-09', freq="D")
close = df_xrp_2y["Close"].tolist()
s_xrp = pd.DataFrame({"Close": close}, index=Index)


s_xrp = s_xrp.resample(rule="M",how=np.std)
s_xrp = s_xrp.rename(columns={"Close":"Monthly Deviation"})

# %matplotlib notebook

s_xrp.plot(title='Ripple Monthly Deviation of Closing Price in Past Two Years', figsize=(10,7), color='r', alpha=0.5)

plt.savefig("graphs/deviation/Ripple_deviation_line.png")

# %%
# %matplotlib notebook
daily_c_pct = df_bch_2y["Daily Change Percent(%)"]
daily_c_pct.plot(kind='hist', title="Bitcoin Cash Daily Change Percentage Distribution", color='blue')

plt.savefig("graphs/distribution/BCH_pct_frq.png")

# %%
# %matplotlib notebook
sb.distplot(df_bch_2y["Close"], axlabel="Daily Closing Price")
plt.title("Bitcoin Cash Price Frequency 2017-07-24 ~ 2018-11-09")

plt.savefig("graphs/distribution/BCH_price_frq.png")

# %%
#print(df_bch_2y)

# %%
Index = pd.DatetimeIndex(start='2017-07-24', end='2018-11-09', freq="D")
close = df_bch_2y["Close"].tolist()
s_bch = pd.DataFrame({"Close": close}, index=Index)


s_bch = s_bch.resample(rule="M",how=np.std)
s_bch = s_bch.rename(columns={"Close":"Monthly Deviation"})

# %matplotlib notebook

s_bch.plot(title='BCH Monthly Deviation of Closing Price in Past Two Years', figsize=(10,7), color='r', alpha=0.5)

plt.savefig("graphs/deviation/BCH_deviation_line.png")

# %%
# %matplotlib notebook
daily_c_pct = df_eos_2y["Daily Change Percent(%)"]
daily_c_pct.plot(kind='hist', title="EOS Daily Change Percentage Distribution", color='blue')

plt.savefig("graphs/distribution/EOS_pct_frq.png")

# %%
# %matplotlib notebook
sb.distplot(df_eos_2y["Close"], axlabel="Daily Closing Price")
plt.title("EOS Daily Price Frequency 2017-07-02 ~ 2018-11-09")

plt.savefig("graphs/distribution/EOS_price_frq.png")

# %%
Index = pd.DatetimeIndex(start='2017-07-02', end='2018-11-09', freq="D")
close = df_eos_2y["Close"].tolist()
s_eos = pd.DataFrame({"Close": close}, index=Index)


s_eos = s_eth.resample(rule="M",how=np.std)
s_eos = s_eth.rename(columns={"Close":"Monthly Deviation"})

# %matplotlib notebook

s_eos.plot(title='EOS Monthly Deviation of Closing Price in Past Two Years', figsize=(10,7), color='r', alpha=0.5)

plt.savefig("graphs/deviation/EOS_deviation_line.png")
